# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df=pd.read_csv("water_treatment_data.csv", na_values = '?')

backup = df.copy() #Always backup your data!

# %%
df.head()
# Out:
#        Date      Q-E  ZN-E  PH-E  DBO-E  DQO-E   SS-E  SSV-E  SED-E  COND-E  \
# 0  D-1/3/90  44101.0   1.5   7.8    NaN  407.0  166.0   66.3    4.5    2110
# 1  D-2/3/90  39024.0   3.0   7.7    NaN  443.0  214.0   69.2    6.5    2660
# 2  D-4/3/90  32229.0   5.0   7.6    NaN  528.0  186.0   69.9    3.4    1666
# 3  D-5/3/90  35023.0   3.5   7.9  205.0  588.0  192.0   65.6    4.5    2430
# 4  D-6/3/90  36924.0   1.5   8.0  242.0  496.0  176.0   64.8    4.0    2110
#
#    PH-P  DBO-P  SS-P  SSV-P  SED-P  COND-P  PH-D  DBO-D  DQO-D  SS-D  SSV-D  \
# 0   7.9    NaN   228   70.2    5.5    2120   7.9    NaN  280.0  94.0   72.3
# 1   7.7    NaN   244   75.4    7.7    2570   7.6    NaN  474.0  96.0   79.2
# 2   7.7    NaN   220   72.7    4.5    1594   7.7    NaN  272.0  92.0   78.3
# 3   7.8  236.0   268   73.1    8.5    2280   7.8  158.0  376.0  96.0   77.1
# 4   7.9    NaN   236   57.6    4.5    2020   7.8    NaN  372.0  88.0   68.2
#
# ...

# %%
df.dtypes
# Out:
# Date         object
# Q-E         float64
# ZN-E        float64
# PH-E        float64
# DBO-E       float64
# DQO-E       float64
# SS-E        float64
# SSV-E       float64
# SED-E       float64
# COND-E        int64
# PH-P        float64
# DBO-P       float64
# SS-P          int64
# SSV-P       float64
# SED-P       float64
# COND-P        int64
# PH-D        float64
# DBO-D       float64
# DQO-D       float64
# SS-D        float64
# SSV-D       float64
# SED-D       float64
# COND-D        int64
# PH-S        float64
# DBO-S       float64
# DQO-S       float64
# SS-S        float64
# SSV-S       float64
# SED-S       float64
# COND-S      float64
# RD-DBO-P    float64
# RD-SS-P     float64
# RD-SED-P    float64
# RD-DBO-S    float64
# RD-DQO-S    float64
# RD-DBO-G    float64
# RD-DQO-G    float64
# RD-SS-G     float64
# RD-SED-G    float64
# dtype: object

# %%
df.hist(figsize=(14,14), xrot= -45)
plt.show()

# %%
df.describe()
# Out:
#                 Q-E        ZN-E        PH-E       DBO-E       DQO-E  \
# count    509.000000  524.000000  527.000000  504.000000  521.000000
# mean   37226.567780    2.359065    7.810057  188.714286  406.898273
# std     6635.999806    2.749509    0.246175   62.062831  120.362974
# min    10050.000000    0.100000    6.900000   31.000000   81.000000
# 25%    32888.000000    0.900000    7.600000  146.750000  325.000000
# 50%    35990.000000    1.500000    7.800000  182.500000  400.000000
# 75%    41372.000000    3.000000    8.000000  223.000000  478.000000
# max    60081.000000   33.500000    8.700000  438.000000  941.000000
#
#               SS-E       SSV-E       SED-E       COND-E        PH-P  \
# count   526.000000  516.000000  502.000000   527.000000  527.000000
# mean    227.444867   61.393217    4.593825  1478.620493    7.829981
# std     135.940589   12.415264    2.743947   394.898019    0.226925
# min      98.000000   13.200000    0.400000   651.000000    7.300000
# ...

# %%
#Format Date column
print(type(df.Date[0]))
print(df.Date[0])
# Out:
# <class 'str'>
# D-1/3/90

# %%
date1 = df.Date[0].lstrip('D-')
print(date1)
print(type(date1))
# Out:
# 1/3/90
# <class 'str'>

# %%
date2 = pd.to_datetime(date1)
print(date2)
type(date2)
# Out:
# 1990-01-03 00:00:00
# pandas._libs.tslibs.timestamps.Timestamp

# %%
for date in df['Date'].items:
    df.Date[date] = date.lstrip('D-')
    df.Date[date] = pd.to_datetime(date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-a131c07c48e7> in <module>()
# ----> 1 for date in df['Date'].items:
#       2     df.Date[date] = date.lstrip('D-')
#       3     df.Date[date] = pd.to_datetime(date)
#
# TypeError: 'method' object is not iterable
